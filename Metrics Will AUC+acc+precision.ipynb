# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
import tensorflow as tf
tf.config.set_soft_device_placement(True)
tf.debugging.set_log_device_placement(True)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14842022431508853691
# ]

# %%
import pickle

with open('standarized_sn.data', 'rb') as filehandle:
    # read the data as binary data stream
    standarized_sn = pickle.load(filehandle)

with open('flux_sn.data', 'rb') as filehandle:
    # read the data as binary data stream
    flux_sn = pickle.load(filehandle)

with open('flux_host.data', 'rb') as filehandle:
    # read the data as binary data stream
    flux_host = pickle.load(filehandle)

with open('standarized_hosts.data', 'rb') as filehandle:
    # read the data as binary data stream
    standarized_host = pickle.load(filehandle)

with open('wave_sn.data', 'rb') as filehandle:
    # read the data as binary data stream
    wave_em_sn = pickle.load(filehandle)

with open('wave_host.data', 'rb') as filehandle:
    # read the data as binary data stream
    wave_em_host = pickle.load(filehandle)

with open('wave_obs.data', 'rb') as filehandle:
    # read the data as binary data stream
    wave_obs = pickle.load(filehandle)

# %%
with open('standarized_em_host.data', 'rb') as filehandle:
    # read the data as binary data stream
    standarized_em_host = pickle.load(filehandle)
with open('standarized_em_sn.data', 'rb') as filehandle:
    # read the data as binary data stream
    standarized_em_sn = pickle.load(filehandle)

# %%
from numpy.random import seed
seed(1)
import pickle
import numpy as np
from datetime import datetime
import os

import tensorflow as tf
from tensorflow import keras
from matplotlib import pyplot as plt
from tensorflow.keras import regularizers, callbacks
from tensorflow.keras.layers import (Input, Dense, Activation, ZeroPadding1D, 
BatchNormalization, Flatten, Reshape, Conv1D, MaxPooling1D, Dropout,Add, LSTM,Embedding)
from tensorflow.keras.initializers import glorot_normal, glorot_uniform
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model

from tensorflow.keras import utils


#from desispec.interpolation import resample_flux

from tensorflow.keras import backend as K



plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.tab10.colors)
#plt.rcParamsDefault['axes.prop_cycle']
plt.rcParams['font.size'] = 16
plt.rcParams['axes.grid'] = True
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
plt.rc('grid',alpha=0.3,linestyle='--')

# %%
from numpy.random import seed
seed(1)
import pickle
import numpy as np
from datetime import datetime
import os

# %%
auc = tf.keras.metrics.AUC(curve='PR')
precision = tf.keras.metrics.Precision()

# %%
def network_aucprecision(input_shape, learning_rate=0.0005, reg=0.0032, dropout=0.7436, seed=None):
    """ 
    Args:
    input_shape -- shape of the input spectra
    regularization_strength -- regularization factor
    dropout -- dropout rate
    seed -- seed of initializer
    Returns:
    model -- a Model() instance in Keras
    """

    X_input = Input(input_shape, name='Input_Spec')

    with K.name_scope('Conv_1'):
        X = Conv1D(filters=8, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X_input)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(pool_size= 2)(X)

    with K.name_scope('Conv_2'):
        X = Conv1D(filters=16, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
    with K.name_scope('Conv_3'):
        X = Conv1D(filters=32, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
        
    with K.name_scope('Conv_4'):
        X = Conv1D(filters=64, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)

        
    # FLATTEN -> FULLYCONNECTED
    with K.name_scope('Dense_Layer'):
        X = Flatten()(X)
        X = Dense(256, kernel_regularizer=regularizers.l2(reg),
                  activation='relu')(X)
        X = Dropout(rate=dropout, seed=seed)(X)
    
    with K.name_scope('Output_Layer'):
        X = Dense(1, kernel_regularizer=regularizers.l2(reg),
              activation='sigmoid',name='Output_Classes')(X)

    model = Model(inputs=X_input, outputs=X, name='SNnet')
    model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy',
                  metrics=[auc,precision,'accuracy'])
    return model

# %%
def roc_pr_cm_histAUCPrecision(X,y):
    # Splitting the data 
    X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.25)
    """Trying from the blog"""
    from keras.models import Sequential
    from keras.layers import Dense
    # Classifier
    from keras.wrappers.scikit_learn import KerasClassifier
    keras_model = network_aucprecision((400,1))

    keras_model.fit(X_train, y_train, epochs=30, batch_size=64, verbose=1)

    from sklearn.metrics import roc_curve
    y_pred_keras = keras_model.predict(X_test).ravel()
    fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred_keras)

    # Area under the curve
    from sklearn.metrics import auc
    auc_keras = auc(fpr_keras, tpr_keras)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show()
    
    ############
    import random
    import pylab as pl
    import numpy as np
    from sklearn import svm, datasets
    from sklearn.metrics import precision_recall_curve
    from sklearn.metrics import auc

    """# The source code uses decision_function
    but that is only applicable to sequential class and not the model class that our classifer uses.
    Check here for more reference: https://stats.stackexchange.com/questions/329857/what-is-the-difference-between-decision-function-predict-proba-and-predict-fun"""
    y_score = keras_model.predict(X_test).ravel() 


    # Average precision score
    from sklearn.metrics import average_precision_score
    average_precision = average_precision_score(y_test, y_score)

    print('Average precision-recall score: {0:0.2f}'.format(average_precision))

    #https://scikit-plot.readthedocs.io/en/stable/Quickstart.html
    #Used Professor's Benzvi's code for PR curve

    from sklearn.metrics import precision_recall_curve
    precision, recall, _ = precision_recall_curve(y_test, y_pred_keras)
    plt.figure()
    plt.step(recall, precision, where='post')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('Precision Recall Curve with average precision of {0:0.2f}'.format(average_precision))
    
    ########
    
    from sklearn.metrics import confusion_matrix

    y_pred = y_pred_keras

    def plotConfusionMatrix(y_true, y_pred, classes=["Hosts", "Type IAs", "Type IIPs"], cmap=plt.cm.gray, title="Normalized Confusion Matrix"):
        from sklearn.metrics import accuracy_score
        from sklearn.metrics import confusion_matrix
        # Compute confusion matrix
        cm = confusion_matrix(y_true, y_pred)
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
        #print(cm)
        print("Accuracy: ", accuracy_score(y_true, y_pred))
        fig, ax = plt.subplots()
        im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
        ax.figure.colorbar(im, ax=ax)
        # We want to show all ticks...
        ax.set(xticks=np.arange(cm.shape[1]),
               yticks=np.arange(cm.shape[0]),
               xticklabels=classes, yticklabels=classes,
               title=title,
               ylabel='True label',
               xlabel='Predicted label')
        # Rotate the tick labels and set their alignment.
        plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
                 rotation_mode="anchor")
        # create text annotations
        fmt = '.3f'
        thresh = cm.max() / 2.
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                ax.text(j, i, format(cm[i, j], fmt),
                        ha="center", va="center",
                        color="white" if cm[i, j] < thresh else "black")
        fig.tight_layout()
        plt.ylim([1.5, -.5])

        plt.show()
        return ax

    for i in range(len(y_pred)):
        y_pred[i]=round(y_pred[i])

    plotConfusionMatrix(y_true=y_test, y_pred=y_pred, title="Normalized Conf. Matrix")
    
    ###################
    history = keras_model.fit(X_train, y_train, epochs=30, batch_size=64, validation_data=(X_test, y_test), shuffle=True)
    plt.plot(history.history['precision'])
    plt.plot(history.history['val_precision'])
    a = np.mean(history.history['precision'])
    v = np.mean(history.history['val_precision'])
    plt.title('mean_precision = {0:0.3f}, mean_val_precision = {1:0.3f}'.format(a,v))
    plt.ylabel('precision')
    plt.ylim([0.5,1])
    plt.xlabel('epoch')
    plt.legend(['precision', 'val_precision'], loc='best')
    plt.show()
    
    plt.plot(history.history['auc'])
    plt.plot(history.history['val_auc'])
    a = np.mean(history.history['auc'])
    v = np.mean(history.history['val_auc'])
    plt.title('mean_auc = {0:0.3f}, mean_val_auc = {1:0.3f}'.format(a,v))
    plt.ylabel('AUC')
    plt.ylim([0.5,1])
    plt.xlabel('epoch')
    plt.legend(['auc', 'val_auc'], loc='best')
    plt.show()

# %%
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
X = np.concatenate([standarized_sn,standarized_host]).reshape(-1,400,1)
y = np.concatenate([np.zeros(standarized_sn.shape[0]),np.ones(standarized_host.shape[0])])

# %%
model2=network_aucprecision((400,1))

# %%
permute = np.random.permutation(y.shape[-1])
l = len(X)
hist = model2.fit(X[permute][:l],y[permute][:l],batch_size=64,epochs=50,validation_split=0.25,shuffle=True)
# Out:
# Train on 11184 samples, validate on 3729 samples
# Epoch 1/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.3197 - auc: 0.9794 - precision: 0.9152 - acc: 0.9137 - val_loss: 0.6574 - val_auc: 0.9345 - val_precision: 0.7682 - val_acc: 0.7946
# Epoch 2/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.3119 - auc: 0.9803 - precision: 0.9182 - acc: 0.9176 - val_loss: 0.5537 - val_auc: 0.9481 - val_precision: 0.8090 - val_acc: 0.8343
# Epoch 3/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.3064 - auc: 0.9814 - precision: 0.9237 - acc: 0.9208 - val_loss: 0.6724 - val_auc: 0.9375 - val_precision: 0.7455 - val_acc: 0.7643
# Epoch 4/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.3020 - auc: 0.9821 - precision: 0.9207 - acc: 0.9195 - val_loss: 1.0606 - val_auc: 0.8722 - val_precision: 0.7258 - val_acc: 0.7436
# Epoch 5/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2988 - auc: 0.9834 - precision: 0.9221 - acc: 0.9213 - val_loss: 1.1742 - val_auc: 0.8011 - val_precision: 0.7271 - val_acc: 0.7372
# Epoch 6/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2933 - auc: 0.9836 - precision: 0.9261 - acc: 0.9254 - val_loss: 0.4377 - val_auc: 0.9449 - val_precision: 0.8614 - val_acc: 0.8667
# Epoch 7/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2897 - auc: 0.9840 - precision: 0.9286 - acc: 0.9262 - val_loss: 0.4213 - val_auc: 0.9724 - val_precision: 0.8385 - val_acc: 0.8670
# Epoch 8/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2910 - auc: 0.9841 - precision: 0.9272 - acc: 0.9255 - val_loss: 1.7498 - val_auc: 0.7464 - val_precision: 0.7269 - val_acc: 0.7447
# Epoch 9/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2894 - auc: 0.9843 - precision: 0.9282 - acc: 0.9267 - val_loss: 0.4188 - val_auc: 0.9696 - val_precision: 0.8494 - val_acc: 0.8729
# Epoch 10/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2801 - auc: 0.9861 - precision: 0.9315 - acc: 0.9299 - val_loss: 0.4299 - val_auc: 0.9736 - val_precision: 0.8395 - val_acc: 0.8659
# Epoch 11/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2708 - auc: 0.9873 - precision: 0.9358 - acc: 0.9333 - val_loss: 0.3059 - val_auc: 0.9857 - val_precision: 0.9519 - val_acc: 0.9163
# Epoch 12/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2753 - auc: 0.9873 - precision: 0.9321 - acc: 0.9315 - val_loss: 0.3172 - val_auc: 0.9817 - val_precision: 0.9330 - val_acc: 0.9110
# Epoch 13/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2677 - auc: 0.9879 - precision: 0.9367 - acc: 0.9336 - val_loss: 0.5538 - val_auc: 0.9609 - val_precision: 0.8251 - val_acc: 0.8549
# Epoch 14/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2704 - auc: 0.9881 - precision: 0.9346 - acc: 0.9325 - val_loss: 0.7194 - val_auc: 0.9589 - val_precision: 0.9567 - val_acc: 0.7345
# Epoch 15/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2679 - auc: 0.9883 - precision: 0.9367 - acc: 0.9345 - val_loss: 0.4474 - val_auc: 0.9772 - val_precision: 0.8305 - val_acc: 0.8600
# Epoch 16/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2581 - auc: 0.9899 - precision: 0.9407 - acc: 0.9377 - val_loss: 0.2865 - val_auc: 0.9863 - val_precision: 0.9361 - val_acc: 0.9292
# Epoch 17/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2670 - auc: 0.9877 - precision: 0.9392 - acc: 0.9391 - val_loss: 0.3135 - val_auc: 0.9846 - val_precision: 0.9446 - val_acc: 0.9153
# Epoch 18/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2638 - auc: 0.9889 - precision: 0.9393 - acc: 0.9390 - val_loss: 0.5205 - val_auc: 0.9602 - val_precision: 0.7956 - val_acc: 0.8241
# Epoch 19/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2580 - auc: 0.9902 - precision: 0.9394 - acc: 0.9382 - val_loss: 0.5929 - val_auc: 0.9603 - val_precision: 0.8031 - val_acc: 0.8327
# Epoch 20/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2520 - auc: 0.9915 - precision: 0.9440 - acc: 0.9430 - val_loss: 0.3500 - val_auc: 0.9742 - val_precision: 0.9200 - val_acc: 0.9019
# Epoch 21/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2593 - auc: 0.9897 - precision: 0.9424 - acc: 0.9394 - val_loss: 0.5480 - val_auc: 0.9513 - val_precision: 0.8175 - val_acc: 0.8439
# Epoch 22/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2503 - auc: 0.9909 - precision: 0.9464 - acc: 0.9440 - val_loss: 0.3255 - val_auc: 0.9778 - val_precision: 0.9133 - val_acc: 0.9123
# Epoch 23/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2534 - auc: 0.9909 - precision: 0.9420 - acc: 0.9388 - val_loss: 0.3349 - val_auc: 0.9760 - val_precision: 0.9049 - val_acc: 0.9064
# Epoch 24/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2370 - auc: 0.9925 - precision: 0.9496 - acc: 0.9494 - val_loss: 0.3431 - val_auc: 0.9749 - val_precision: 0.9078 - val_acc: 0.9005
# Epoch 25/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2455 - auc: 0.9914 - precision: 0.9488 - acc: 0.9462 - val_loss: 0.3610 - val_auc: 0.9779 - val_precision: 0.9354 - val_acc: 0.8892
# Epoch 26/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2422 - auc: 0.9918 - precision: 0.9493 - acc: 0.9461 - val_loss: 0.4774 - val_auc: 0.9567 - val_precision: 0.8481 - val_acc: 0.8732
# Epoch 27/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2299 - auc: 0.9938 - precision: 0.9521 - acc: 0.9489 - val_loss: 0.3303 - val_auc: 0.9755 - val_precision: 0.9226 - val_acc: 0.9163
# Epoch 28/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2345 - auc: 0.9936 - precision: 0.9505 - acc: 0.9494 - val_loss: 0.4207 - val_auc: 0.9680 - val_precision: 0.8561 - val_acc: 0.8774
# Epoch 29/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2292 - auc: 0.9935 - precision: 0.9555 - acc: 0.9512 - val_loss: 0.3305 - val_auc: 0.9794 - val_precision: 0.9386 - val_acc: 0.9080
# Epoch 30/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2373 - auc: 0.9927 - precision: 0.9521 - acc: 0.9480 - val_loss: 0.4455 - val_auc: 0.9649 - val_precision: 0.8513 - val_acc: 0.8729
# Epoch 31/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2347 - auc: 0.9930 - precision: 0.9504 - acc: 0.9474 - val_loss: 0.4634 - val_auc: 0.9504 - val_precision: 0.8775 - val_acc: 0.8788
# Epoch 32/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2275 - auc: 0.9938 - precision: 0.9540 - acc: 0.9525 - val_loss: 0.4219 - val_auc: 0.9595 - val_precision: 0.9216 - val_acc: 0.8839
# Epoch 33/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2203 - auc: 0.9946 - precision: 0.9588 - acc: 0.9544 - val_loss: 1.0848 - val_auc: 0.8271 - val_precision: 0.7490 - val_acc: 0.7670
# Epoch 34/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2316 - auc: 0.9940 - precision: 0.9541 - acc: 0.9520 - val_loss: 0.5348 - val_auc: 0.9438 - val_precision: 0.8388 - val_acc: 0.8522
# Epoch 35/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2197 - auc: 0.9952 - precision: 0.9570 - acc: 0.9545 - val_loss: 0.5533 - val_auc: 0.9325 - val_precision: 0.8536 - val_acc: 0.8697
# Epoch 36/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2139 - auc: 0.9952 - precision: 0.9624 - acc: 0.9590 - val_loss: 1.1440 - val_auc: 0.8279 - val_precision: 0.7391 - val_acc: 0.7581
# Epoch 37/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2233 - auc: 0.9943 - precision: 0.9573 - acc: 0.9551 - val_loss: 0.3699 - val_auc: 0.9718 - val_precision: 0.9016 - val_acc: 0.9102
# Epoch 38/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2186 - auc: 0.9947 - precision: 0.9605 - acc: 0.9580 - val_loss: 0.4203 - val_auc: 0.9681 - val_precision: 0.8662 - val_acc: 0.8866
# Epoch 39/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2131 - auc: 0.9952 - precision: 0.9618 - acc: 0.9577 - val_loss: 0.4220 - val_auc: 0.9639 - val_precision: 0.8847 - val_acc: 0.8783
# Epoch 40/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2167 - auc: 0.9944 - precision: 0.9621 - acc: 0.9588 - val_loss: 0.6645 - val_auc: 0.9210 - val_precision: 0.8072 - val_acc: 0.8351
# Epoch 41/50
# 11184/11184 [==============================] - 14s 1ms/sample - loss: 0.2099 - auc: 0.9959 - precision: 0.9618 - acc: 0.9598 - val_loss: 0.3529 - val_auc: 0.9803 - val_precision: 0.9413 - val_acc: 0.9027
# Epoch 42/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2093 - auc: 0.9958 - precision: 0.9641 - acc: 0.9596 - val_loss: 0.3597 - val_auc: 0.9780 - val_precision: 0.9439 - val_acc: 0.8943
# Epoch 43/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2080 - auc: 0.9961 - precision: 0.9624 - acc: 0.9595 - val_loss: 0.9870 - val_auc: 0.8986 - val_precision: 0.7353 - val_acc: 0.7554
# Epoch 44/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2017 - auc: 0.9964 - precision: 0.9669 - acc: 0.9633 - val_loss: 0.6294 - val_auc: 0.9374 - val_precision: 0.8417 - val_acc: 0.8587
# Epoch 45/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2091 - auc: 0.9957 - precision: 0.9633 - acc: 0.9604 - val_loss: 0.5297 - val_auc: 0.9457 - val_precision: 0.8388 - val_acc: 0.8581
# Epoch 46/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2082 - auc: 0.9956 - precision: 0.9643 - acc: 0.9612 - val_loss: 0.9771 - val_auc: 0.8431 - val_precision: 0.7782 - val_acc: 0.7919
# Epoch 47/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2156 - auc: 0.9950 - precision: 0.9605 - acc: 0.9584 - val_loss: 1.0435 - val_auc: 0.8627 - val_precision: 0.7874 - val_acc: 0.8080
# Epoch 48/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2058 - auc: 0.9963 - precision: 0.9642 - acc: 0.9607 - val_loss: 0.3258 - val_auc: 0.9775 - val_precision: 0.9249 - val_acc: 0.9220
# Epoch 49/50
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2099 - auc: 0.9956 - precision: 0.9654 - acc: 0.9624 - val_loss: 1.1711 - val_auc: 0.8366 - val_precision: 0.7499 - val_acc: 0.7734
# Epoch 50/50
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2166 - auc: 0.9951 - precision: 0.9621 - acc: 0.9576 - val_loss: 0.8350 - val_auc: 0.9067 - val_precision: 0.7958 - val_acc: 0.8241

# %%
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
a = np.mean(hist.history['acc'])
v = np.mean(hist.history['val_acc'])
plt.title('mean_acc = {0:0.3f}, mean_val_acc = {1:0.3f}'.format(a,v))
plt.ylabel('accuracy')
plt.ylim([0.5,1])
plt.xlabel('epoch')
plt.legend(['acc', 'val_acc'], loc='best')
plt.show()
plt.tight_layout()

plt.plot(hist.history['auc'])
plt.plot(hist.history['val_auc'])
a = np.mean(hist.history['auc'])
v = np.mean(hist.history['val_auc'])
plt.title('mean_auc = {0:0.3f}, mean_val_auc = {1:0.3f}'.format(a,v))
plt.ylabel('AUC')
plt.ylim([0.5,1])
plt.xlabel('epoch')
plt.legend(['auc', 'val_auc'], loc='best')
plt.show()

plt.plot(hist.history['precision'])
plt.plot(hist.history['val_precision'])
a = np.mean(hist.history['precision'])
v = np.mean(hist.history['val_precision'])
plt.title('mean_precision = {0:0.3f}, mean_val_precision = {1:0.3f}'.format(a,v))
plt.ylabel('precision')
plt.ylim([0.5,1])
plt.xlabel('epoch')
plt.legend(['precision', 'val_precision'], loc='best')
plt.show()
plt.tight_layout()

# %%
roc_pr_cm_histAUCPrecision(X,y)
# Out:
# Using TensorFlow backend.
# Epoch 1/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 1.6300 - auc: 0.7392 - precision: 0.6868 - acc: 0.6633
# Epoch 2/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 1.0757 - auc: 0.8230 - precision: 0.7178 - acc: 0.7034
# Epoch 3/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.8828 - auc: 0.8527 - precision: 0.7485 - acc: 0.7329
# Epoch 4/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.7728 - auc: 0.8716 - precision: 0.7757 - acc: 0.7580
# Epoch 5/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.6930 - auc: 0.8915 - precision: 0.7934 - acc: 0.7808
# Epoch 6/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.6277 - auc: 0.9046 - precision: 0.8200 - acc: 0.8088
# Epoch 7/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.5783 - auc: 0.9159 - precision: 0.8342 - acc: 0.8273
# Epoch 8/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.5352 - auc: 0.9290 - precision: 0.8457 - acc: 0.8402
# Epoch 9/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.5031 - auc: 0.9375 - precision: 0.8571 - acc: 0.8523
# Epoch 10/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.4805 - auc: 0.9425 - precision: 0.8667 - acc: 0.8628
# Epoch 11/30
# 11184/11184 [==============================] - 11s 998us/sample - loss: 0.4567 - auc: 0.9477 - precision: 0.8679 - acc: 0.8653
# Epoch 12/30
# 11184/11184 [==============================] - 11s 999us/sample - loss: 0.4323 - auc: 0.9545 - precision: 0.8752 - acc: 0.8715
# Epoch 13/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.4185 - auc: 0.9556 - precision: 0.8806 - acc: 0.8783
# Epoch 14/30
# 11184/11184 [==============================] - 11s 991us/sample - loss: 0.4069 - auc: 0.9583 - precision: 0.8834 - acc: 0.8807
# Epoch 15/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3999 - auc: 0.9594 - precision: 0.8878 - acc: 0.8844
# Epoch 16/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3831 - auc: 0.9653 - precision: 0.8933 - acc: 0.8912
# Epoch 17/30
# 11184/11184 [==============================] - 11s 996us/sample - loss: 0.3674 - auc: 0.9679 - precision: 0.9009 - acc: 0.8965
# Epoch 18/30
# 11184/11184 [==============================] - 11s 997us/sample - loss: 0.3664 - auc: 0.9679 - precision: 0.9005 - acc: 0.8970
# Epoch 19/30
# 11184/11184 [==============================] - 11s 989us/sample - loss: 0.3571 - auc: 0.9693 - precision: 0.9027 - acc: 0.9004
# Epoch 20/30
# 11184/11184 [==============================] - 11s 997us/sample - loss: 0.3461 - auc: 0.9722 - precision: 0.9072 - acc: 0.9045
# Epoch 21/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3451 - auc: 0.9721 - precision: 0.9052 - acc: 0.9044
# Epoch 22/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3286 - auc: 0.9762 - precision: 0.9110 - acc: 0.9097
# Epoch 23/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.3281 - auc: 0.9766 - precision: 0.9123 - acc: 0.9101
# Epoch 24/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.3064 - auc: 0.9813 - precision: 0.9158 - acc: 0.9159
# Epoch 25/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.3091 - auc: 0.9795 - precision: 0.9197 - acc: 0.9171
# Epoch 26/30
# 11184/11184 [==============================] - 11s 989us/sample - loss: 0.3117 - auc: 0.9796 - precision: 0.9159 - acc: 0.9142
# Epoch 27/30
# 11184/11184 [==============================] - 11s 998us/sample - loss: 0.3021 - auc: 0.9812 - precision: 0.9217 - acc: 0.9168
# Epoch 28/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2956 - auc: 0.9813 - precision: 0.9249 - acc: 0.9237
# Epoch 29/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2891 - auc: 0.9834 - precision: 0.9276 - acc: 0.9249
# Epoch 30/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2878 - auc: 0.9839 - precision: 0.9259 - acc: 0.9252
# Average precision-recall score: 0.97
# Normalized confusion matrix
# Accuracy:  0.8943416465540359
# Train on 11184 samples, validate on 3729 samples
# Epoch 1/30
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2827 - auc: 0.9847 - precision: 0.9308 - acc: 0.9299 - val_loss: 0.3211 - val_auc: 0.9782 - val_precision: 0.9302 - val_acc: 0.9061
# Epoch 2/30
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2785 - auc: 0.9857 - precision: 0.9313 - acc: 0.9286 - val_loss: 0.6167 - val_auc: 0.9112 - val_precision: 0.8238 - val_acc: 0.8332
# Epoch 3/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2782 - auc: 0.9850 - precision: 0.9342 - acc: 0.9324 - val_loss: 0.3047 - val_auc: 0.9794 - val_precision: 0.9246 - val_acc: 0.9230
# Epoch 4/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2855 - auc: 0.9846 - precision: 0.9300 - acc: 0.9271 - val_loss: 0.3855 - val_auc: 0.9713 - val_precision: 0.9309 - val_acc: 0.8726
# Epoch 5/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2794 - auc: 0.9859 - precision: 0.9298 - acc: 0.9284 - val_loss: 0.7016 - val_auc: 0.9342 - val_precision: 0.7229 - val_acc: 0.7420
# Epoch 6/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2713 - auc: 0.9872 - precision: 0.9324 - acc: 0.9286 - val_loss: 0.4190 - val_auc: 0.9665 - val_precision: 0.8626 - val_acc: 0.8783
# Epoch 7/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2722 - auc: 0.9872 - precision: 0.9374 - acc: 0.9325 - val_loss: 0.4259 - val_auc: 0.9593 - val_precision: 0.8474 - val_acc: 0.8710
# Epoch 8/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2634 - auc: 0.9884 - precision: 0.9370 - acc: 0.9373 - val_loss: 0.3439 - val_auc: 0.9712 - val_precision: 0.9028 - val_acc: 0.8989
# Epoch 9/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2640 - auc: 0.9882 - precision: 0.9386 - acc: 0.9355 - val_loss: 0.3283 - val_auc: 0.9793 - val_precision: 0.8869 - val_acc: 0.9040
# Epoch 10/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2517 - auc: 0.9905 - precision: 0.9410 - acc: 0.9375 - val_loss: 0.3584 - val_auc: 0.9741 - val_precision: 0.8731 - val_acc: 0.8922
# Epoch 11/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2500 - auc: 0.9909 - precision: 0.9428 - acc: 0.9418 - val_loss: 0.6019 - val_auc: 0.8973 - val_precision: 0.8390 - val_acc: 0.8563
# Epoch 12/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2444 - auc: 0.9907 - precision: 0.9472 - acc: 0.9433 - val_loss: 0.3522 - val_auc: 0.9752 - val_precision: 0.8851 - val_acc: 0.9067
# Epoch 13/30
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2435 - auc: 0.9904 - precision: 0.9461 - acc: 0.9429 - val_loss: 0.5739 - val_auc: 0.9393 - val_precision: 0.7956 - val_acc: 0.8257
# Epoch 14/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2545 - auc: 0.9899 - precision: 0.9426 - acc: 0.9395 - val_loss: 0.5116 - val_auc: 0.9619 - val_precision: 0.8228 - val_acc: 0.8522
# Epoch 15/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2435 - auc: 0.9912 - precision: 0.9470 - acc: 0.9446 - val_loss: 0.6791 - val_auc: 0.9396 - val_precision: 0.7763 - val_acc: 0.8061
# Epoch 16/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2413 - auc: 0.9918 - precision: 0.9474 - acc: 0.9447 - val_loss: 0.7624 - val_auc: 0.9303 - val_precision: 0.7466 - val_acc: 0.7713
# Epoch 17/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2341 - auc: 0.9930 - precision: 0.9507 - acc: 0.9472 - val_loss: 0.5023 - val_auc: 0.9592 - val_precision: 0.8415 - val_acc: 0.8707
# Epoch 18/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2291 - auc: 0.9937 - precision: 0.9499 - acc: 0.9481 - val_loss: 0.3363 - val_auc: 0.9751 - val_precision: 0.8974 - val_acc: 0.9051
# Epoch 19/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2312 - auc: 0.9929 - precision: 0.9542 - acc: 0.9514 - val_loss: 0.6324 - val_auc: 0.9420 - val_precision: 0.7740 - val_acc: 0.8029
# Epoch 20/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2275 - auc: 0.9937 - precision: 0.9538 - acc: 0.9514 - val_loss: 0.4522 - val_auc: 0.9625 - val_precision: 0.8493 - val_acc: 0.8772
# Epoch 21/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2283 - auc: 0.9938 - precision: 0.9520 - acc: 0.9494 - val_loss: 0.3166 - val_auc: 0.9784 - val_precision: 0.9201 - val_acc: 0.9174
# Epoch 22/30
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2287 - auc: 0.9938 - precision: 0.9527 - acc: 0.9493 - val_loss: 0.4902 - val_auc: 0.9394 - val_precision: 0.8694 - val_acc: 0.8573
# Epoch 23/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2247 - auc: 0.9938 - precision: 0.9550 - acc: 0.9524 - val_loss: 0.6047 - val_auc: 0.9219 - val_precision: 0.8361 - val_acc: 0.8249
# Epoch 24/30
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2240 - auc: 0.9935 - precision: 0.9573 - acc: 0.9532 - val_loss: 0.3663 - val_auc: 0.9693 - val_precision: 0.9136 - val_acc: 0.8949
# Epoch 25/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2220 - auc: 0.9937 - precision: 0.9566 - acc: 0.9538 - val_loss: 0.4955 - val_auc: 0.9528 - val_precision: 0.8904 - val_acc: 0.8624
# Epoch 26/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2261 - auc: 0.9933 - precision: 0.9564 - acc: 0.9541 - val_loss: 0.4339 - val_auc: 0.9559 - val_precision: 0.8694 - val_acc: 0.8737
# Epoch 27/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2229 - auc: 0.9942 - precision: 0.9578 - acc: 0.9536 - val_loss: 0.3311 - val_auc: 0.9783 - val_precision: 0.9340 - val_acc: 0.9064
# Epoch 28/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2107 - auc: 0.9950 - precision: 0.9606 - acc: 0.9577 - val_loss: 0.3564 - val_auc: 0.9706 - val_precision: 0.9032 - val_acc: 0.9037
# Epoch 29/30
# 11184/11184 [==============================] - 13s 1ms/sample - loss: 0.2129 - auc: 0.9954 - precision: 0.9602 - acc: 0.9565 - val_loss: 0.5043 - val_auc: 0.9525 - val_precision: 0.8518 - val_acc: 0.8635
# Epoch 30/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.2171 - auc: 0.9946 - precision: 0.9579 - acc: 0.9557 - val_loss: 0.3477 - val_auc: 0.9711 - val_precision: 0.9167 - val_acc: 0.9072

# %%
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
X_em = np.concatenate([standarized_em_sn,standarized_em_host]).reshape(-1,400,1)
y_em = np.concatenate([np.zeros(standarized_em_sn.shape[0]),np.ones(standarized_em_host.shape[0])])

# %%
roc_pr_cm_histAUCPrecision(X=X_em,y=y_em)
# Out:
# Epoch 1/30
# 11184/11184 [==============================] - 11s 958us/sample - loss: 1.8729 - auc: 0.7090 - acc: 0.6492
# Epoch 2/30
# 11184/11184 [==============================] - 10s 903us/sample - loss: 1.3169 - auc: 0.7703 - acc: 0.6744
# Epoch 3/30
# 11184/11184 [==============================] - 10s 903us/sample - loss: 1.0599 - auc: 0.8022 - acc: 0.6961
# Epoch 4/30
# 11184/11184 [==============================] - 10s 901us/sample - loss: 0.9102 - auc: 0.8255 - acc: 0.7096
# Epoch 5/30
# 11184/11184 [==============================] - 10s 906us/sample - loss: 0.8125 - auc: 0.8422 - acc: 0.7322
# Epoch 6/30
# 11184/11184 [==============================] - 10s 908us/sample - loss: 0.7340 - auc: 0.8647 - acc: 0.7487
# Epoch 7/30
# 11184/11184 [==============================] - 10s 908us/sample - loss: 0.6733 - auc: 0.8822 - acc: 0.7733
# Epoch 8/30
# 11184/11184 [==============================] - 10s 905us/sample - loss: 0.6246 - auc: 0.8976 - acc: 0.7928
# Epoch 9/30
# 11184/11184 [==============================] - 10s 907us/sample - loss: 0.5788 - auc: 0.9131 - acc: 0.8129
# Epoch 10/30
# 11184/11184 [==============================] - 10s 897us/sample - loss: 0.5514 - auc: 0.9223 - acc: 0.8213
# Epoch 11/30
# 11184/11184 [==============================] - 10s 900us/sample - loss: 0.5320 - auc: 0.9278 - acc: 0.8285
# Epoch 12/30
# 11184/11184 [==============================] - 10s 900us/sample - loss: 0.5033 - auc: 0.9366 - acc: 0.8383
# Epoch 13/30
# 11184/11184 [==============================] - 10s 895us/sample - loss: 0.4950 - auc: 0.9389 - acc: 0.8418
# Epoch 14/30
# 11184/11184 [==============================] - 10s 896us/sample - loss: 0.4689 - auc: 0.9472 - acc: 0.8548
# Epoch 15/30
# 11184/11184 [==============================] - 10s 898us/sample - loss: 0.4468 - auc: 0.9543 - acc: 0.8629
# Epoch 16/30
# 11184/11184 [==============================] - 10s 900us/sample - loss: 0.4484 - auc: 0.9531 - acc: 0.8611
# Epoch 17/30
# 11184/11184 [==============================] - 10s 902us/sample - loss: 0.4197 - auc: 0.9603 - acc: 0.8787
# Epoch 18/30
# 11184/11184 [==============================] - 10s 897us/sample - loss: 0.4124 - auc: 0.9616 - acc: 0.8796
# Epoch 19/30
# 11184/11184 [==============================] - 10s 899us/sample - loss: 0.4185 - auc: 0.9608 - acc: 0.8737
# Epoch 20/30
# 11184/11184 [==============================] - 10s 900us/sample - loss: 0.4036 - auc: 0.9633 - acc: 0.8832
# Epoch 21/30
# 11184/11184 [==============================] - 10s 904us/sample - loss: 0.3970 - auc: 0.9666 - acc: 0.8817
# Epoch 22/30
# 11184/11184 [==============================] - 10s 897us/sample - loss: 0.3729 - auc: 0.9720 - acc: 0.8951
# Epoch 23/30
# 11184/11184 [==============================] - 10s 900us/sample - loss: 0.3743 - auc: 0.9710 - acc: 0.8942
# Epoch 24/30
# 11184/11184 [==============================] - 10s 899us/sample - loss: 0.3706 - auc: 0.9726 - acc: 0.8948
# Epoch 25/30
# 11184/11184 [==============================] - 10s 898us/sample - loss: 0.3838 - auc: 0.9682 - acc: 0.8893
# Epoch 26/30
# 11184/11184 [==============================] - 10s 899us/sample - loss: 0.3647 - auc: 0.9746 - acc: 0.9004
# Epoch 27/30
# 11184/11184 [==============================] - 10s 897us/sample - loss: 0.3532 - auc: 0.9766 - acc: 0.9033
# Epoch 28/30
# 11184/11184 [==============================] - 10s 905us/sample - loss: 0.3475 - auc: 0.9775 - acc: 0.9072
# Epoch 29/30
# 11184/11184 [==============================] - 10s 908us/sample - loss: 0.3602 - auc: 0.9748 - acc: 0.9022
# Epoch 30/30
# 11184/11184 [==============================] - 10s 899us/sample - loss: 0.3410 - auc: 0.9793 - acc: 0.9100
# Average precision-recall score: 0.93
# Normalized confusion matrix
# Accuracy:  0.7811745776347546
# Train on 11184 samples, validate on 3729 samples
# Epoch 1/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3375 - auc: 0.9802 - acc: 0.9102 - val_loss: 0.8484 - val_auc: 0.9304 - val_acc: 0.6774
# Epoch 2/30
# 11184/11184 [==============================] - 12s 1ms/sample - loss: 0.3276 - auc: 0.9817 - acc: 0.9137 - val_loss: 0.6875 - val_auc: 0.9472 - val_acc: 0.7667
# Epoch 3/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3429 - auc: 0.9798 - acc: 0.9068 - val_loss: 0.4893 - val_auc: 0.9646 - val_acc: 0.8080
# Epoch 4/30
# 11184/11184 [==============================] - 11s 998us/sample - loss: 0.3289 - auc: 0.9819 - acc: 0.9150 - val_loss: 0.5041 - val_auc: 0.9535 - val_acc: 0.8477
# Epoch 5/30
# 11184/11184 [==============================] - 11s 998us/sample - loss: 0.3212 - auc: 0.9830 - acc: 0.9168 - val_loss: 0.5327 - val_auc: 0.9642 - val_acc: 0.8123
# Epoch 6/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3185 - auc: 0.9834 - acc: 0.9190 - val_loss: 0.5539 - val_auc: 0.9512 - val_acc: 0.8463
# Epoch 7/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3245 - auc: 0.9825 - acc: 0.9181 - val_loss: 0.6771 - val_auc: 0.9417 - val_acc: 0.8099
# Epoch 8/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3149 - auc: 0.9843 - acc: 0.9213 - val_loss: 0.5863 - val_auc: 0.9111 - val_acc: 0.8171
# Epoch 9/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3280 - auc: 0.9810 - acc: 0.9158 - val_loss: 0.5946 - val_auc: 0.9346 - val_acc: 0.8053
# Epoch 10/30
# 11184/11184 [==============================] - 11s 1000us/sample - loss: 0.3119 - auc: 0.9844 - acc: 0.9244 - val_loss: 0.4720 - val_auc: 0.9612 - val_acc: 0.8463
# Epoch 11/30
# 11184/11184 [==============================] - 11s 999us/sample - loss: 0.2958 - auc: 0.9869 - acc: 0.9303 - val_loss: 0.4751 - val_auc: 0.9683 - val_acc: 0.8431
# Epoch 12/30
# 11184/11184 [==============================] - 11s 995us/sample - loss: 0.3096 - auc: 0.9854 - acc: 0.9219 - val_loss: 0.3811 - val_auc: 0.9733 - val_acc: 0.8925
# Epoch 13/30
# 11184/11184 [==============================] - 11s 997us/sample - loss: 0.2990 - auc: 0.9872 - acc: 0.9268 - val_loss: 0.4925 - val_auc: 0.9415 - val_acc: 0.8466
# Epoch 14/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2930 - auc: 0.9883 - acc: 0.9286 - val_loss: 1.0413 - val_auc: 0.9097 - val_acc: 0.6557
# Epoch 15/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2939 - auc: 0.9875 - acc: 0.9317 - val_loss: 0.8380 - val_auc: 0.9025 - val_acc: 0.7753
# Epoch 16/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2987 - auc: 0.9874 - acc: 0.9273 - val_loss: 0.4757 - val_auc: 0.9671 - val_acc: 0.8407
# Epoch 17/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2881 - auc: 0.9897 - acc: 0.9337 - val_loss: 0.5922 - val_auc: 0.9582 - val_acc: 0.7855
# Epoch 18/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2852 - auc: 0.9902 - acc: 0.9345 - val_loss: 0.6018 - val_auc: 0.9142 - val_acc: 0.8372
# Epoch 19/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2728 - auc: 0.9904 - acc: 0.9410 - val_loss: 0.9302 - val_auc: 0.9259 - val_acc: 0.7300
# Epoch 20/30
# 11184/11184 [==============================] - 11s 999us/sample - loss: 0.2922 - auc: 0.9884 - acc: 0.9320 - val_loss: 1.5419 - val_auc: 0.7953 - val_acc: 0.7409
# Epoch 21/30
# 11184/11184 [==============================] - 11s 999us/sample - loss: 0.2815 - auc: 0.9898 - acc: 0.9351 - val_loss: 0.3965 - val_auc: 0.9696 - val_acc: 0.8871
# Epoch 22/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2685 - auc: 0.9918 - acc: 0.9443 - val_loss: 0.3761 - val_auc: 0.9748 - val_acc: 0.8949
# Epoch 23/30
# 11184/11184 [==============================] - 11s 997us/sample - loss: 0.2727 - auc: 0.9902 - acc: 0.9415 - val_loss: 0.5415 - val_auc: 0.9297 - val_acc: 0.8611
# Epoch 24/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2788 - auc: 0.9910 - acc: 0.9370 - val_loss: 0.4770 - val_auc: 0.9721 - val_acc: 0.8410
# Epoch 25/30
# 11184/11184 [==============================] - 11s 999us/sample - loss: 0.2689 - auc: 0.9920 - acc: 0.9427 - val_loss: 0.4928 - val_auc: 0.9497 - val_acc: 0.8616
# Epoch 26/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.2874 - auc: 0.9896 - acc: 0.9374 - val_loss: 1.7351 - val_auc: 0.9411 - val_acc: 0.5184
# Epoch 27/30
# 11184/11184 [==============================] - 11s 997us/sample - loss: 0.2756 - auc: 0.9910 - acc: 0.9417 - val_loss: 3.2549 - val_auc: 0.8507 - val_acc: 0.4653
# Epoch 28/30
# 11184/11184 [==============================] - 11s 997us/sample - loss: 0.2604 - auc: 0.9933 - acc: 0.9495 - val_loss: 0.4056 - val_auc: 0.9681 - val_acc: 0.8780
# Epoch 29/30
# 11184/11184 [==============================] - 11s 999us/sample - loss: 0.2641 - auc: 0.9924 - acc: 0.9481 - val_loss: 0.5521 - val_auc: 0.9329 - val_acc: 0.8691
# Epoch 30/30
# 11184/11184 [==============================] - 11s 999us/sample - loss: 0.2675 - auc: 0.9927 - acc: 0.9409 - val_loss: 0.4899 - val_auc: 0.9511 - val_acc: 0.8426

# %%
permute = np.random.permutation(y_em.shape[0])
l = len(X_em)
hist1 = model2.fit(X_em[permute][:l],y_em[permute][:l],batch_size=64,epochs=30,
                  validation_split=0.25,shuffle=True)
# Out:
# Train on 11184 samples, validate on 3729 samples
# Epoch 1/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.5506 - auc: 0.8954 - acc: 0.8128 - val_loss: 0.9699 - val_auc: 0.8574 - val_acc: 0.7112
# Epoch 2/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.4556 - auc: 0.9424 - acc: 0.8508 - val_loss: 0.8881 - val_auc: 0.8810 - val_acc: 0.5642
# Epoch 3/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.4324 - auc: 0.9482 - acc: 0.8651 - val_loss: 2.0198 - val_auc: 0.8764 - val_acc: 0.4103
# Epoch 4/30
# 11184/11184 [==============================] - 11s 994us/sample - loss: 0.4157 - auc: 0.9555 - acc: 0.8689 - val_loss: 0.4374 - val_auc: 0.9626 - val_acc: 0.8490
# Epoch 5/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3972 - auc: 0.9598 - acc: 0.8791 - val_loss: 0.5755 - val_auc: 0.9184 - val_acc: 0.8219
# Epoch 6/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3918 - auc: 0.9629 - acc: 0.8824 - val_loss: 0.3714 - val_auc: 0.9651 - val_acc: 0.8960
# Epoch 7/30
# 11184/11184 [==============================] - 11s 997us/sample - loss: 0.3901 - auc: 0.9631 - acc: 0.8811 - val_loss: 1.0616 - val_auc: 0.9254 - val_acc: 0.5363
# Epoch 8/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3762 - auc: 0.9682 - acc: 0.8864 - val_loss: 0.5223 - val_auc: 0.9400 - val_acc: 0.8026
# Epoch 9/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3712 - auc: 0.9691 - acc: 0.8875 - val_loss: 1.1950 - val_auc: 0.9112 - val_acc: 0.5168
# Epoch 10/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3565 - auc: 0.9719 - acc: 0.8965 - val_loss: 0.7723 - val_auc: 0.9035 - val_acc: 0.7393
# Epoch 11/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3415 - auc: 0.9756 - acc: 0.8998 - val_loss: 0.4880 - val_auc: 0.9468 - val_acc: 0.8302
# Epoch 12/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3469 - auc: 0.9750 - acc: 0.8972 - val_loss: 0.4810 - val_auc: 0.9270 - val_acc: 0.8370
# Epoch 13/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3496 - auc: 0.9742 - acc: 0.8995 - val_loss: 0.4890 - val_auc: 0.9361 - val_acc: 0.8375
# Epoch 14/30
# 11184/11184 [==============================] - 11s 998us/sample - loss: 0.3365 - auc: 0.9780 - acc: 0.9042 - val_loss: 1.3340 - val_auc: 0.8014 - val_acc: 0.6876
# Epoch 15/30
# 11184/11184 [==============================] - 11s 1000us/sample - loss: 0.3349 - auc: 0.9784 - acc: 0.9050 - val_loss: 1.0979 - val_auc: 0.9158 - val_acc: 0.6289
# Epoch 16/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3403 - auc: 0.9774 - acc: 0.9024 - val_loss: 0.3650 - val_auc: 0.9711 - val_acc: 0.8938
# Epoch 17/30
# 11184/11184 [==============================] - 11s 996us/sample - loss: 0.3426 - auc: 0.9764 - acc: 0.9042 - val_loss: 0.8458 - val_auc: 0.9305 - val_acc: 0.6425
# Epoch 18/30
# 11184/11184 [==============================] - 11s 999us/sample - loss: 0.3331 - auc: 0.9785 - acc: 0.9073 - val_loss: 1.4069 - val_auc: 0.9438 - val_acc: 0.4945
# Epoch 19/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3279 - auc: 0.9806 - acc: 0.9082 - val_loss: 1.7623 - val_auc: 0.8901 - val_acc: 0.4513
# Epoch 20/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3254 - auc: 0.9796 - acc: 0.9121 - val_loss: 1.0221 - val_auc: 0.9469 - val_acc: 0.6508
# Epoch 21/30
# 11184/11184 [==============================] - 11s 997us/sample - loss: 0.3193 - auc: 0.9821 - acc: 0.9143 - val_loss: 0.6343 - val_auc: 0.9407 - val_acc: 0.8311
# Epoch 22/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3096 - auc: 0.9836 - acc: 0.9157 - val_loss: 0.3915 - val_auc: 0.9638 - val_acc: 0.8804
# Epoch 23/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3178 - auc: 0.9827 - acc: 0.9118 - val_loss: 0.9663 - val_auc: 0.8795 - val_acc: 0.8160
# Epoch 24/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3224 - auc: 0.9804 - acc: 0.9129 - val_loss: 1.5853 - val_auc: 0.7635 - val_acc: 0.6986
# Epoch 25/30
# 11184/11184 [==============================] - 11s 997us/sample - loss: 0.3067 - auc: 0.9850 - acc: 0.9201 - val_loss: 0.3310 - val_auc: 0.9809 - val_acc: 0.9075
# Epoch 26/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3242 - auc: 0.9812 - acc: 0.9117 - val_loss: 2.6253 - val_auc: 0.8843 - val_acc: 0.5784
# Epoch 27/30
# 11184/11184 [==============================] - 11s 995us/sample - loss: 0.3051 - auc: 0.9851 - acc: 0.9192 - val_loss: 0.7380 - val_auc: 0.9417 - val_acc: 0.7401
# Epoch 28/30
# 11184/11184 [==============================] - 11s 1ms/sample - loss: 0.3027 - auc: 0.9857 - acc: 0.9214 - val_loss: 1.0917 - val_auc: 0.9422 - val_acc: 0.6897
# Epoch 29/30
# 11184/11184 [==============================] - 11s 998us/sample - loss: 0.3121 - auc: 0.9837 - acc: 0.9173 - val_loss: 0.6347 - val_auc: 0.8979 - val_acc: 0.7573
# Epoch 30/30
# 11184/11184 [==============================] - 11s 998us/sample - loss: 0.3040 - auc: 0.9855 - acc: 0.9209 - val_loss: 0.9062 - val_auc: 0.8657 - val_acc: 0.7509

# %%
plt.plot(hist1.history['acc'])
plt.plot(hist1.history['val_acc'])
a = np.mean(hist1.history['acc'])
v = np.mean(hist1.history['val_acc'])
plt.title('mean_acc = {0:0.3f}, mean_val_acc = {1:0.3f}'.format(a,v))
plt.ylabel('accuracy')
plt.ylim([0.5,1])
plt.xlabel('epoch')
plt.legend(['acc', 'val_acc'], loc='best')
plt.show()

plt.plot(hist1.history['auc'])
plt.plot(hist1.history['val_auc'])
a = np.mean(hist1.history['auc'])
v = np.mean(hist1.history['val_auc'])
plt.title('mean_auc = {0:0.3f}, mean_val_auc = {1:0.3f}'.format(a,v))
plt.ylabel('AUC')
plt.ylim([0.5,1])
plt.xlabel('epoch')
plt.legend(['auc', 'val_auc'], loc='best')
plt.show()
