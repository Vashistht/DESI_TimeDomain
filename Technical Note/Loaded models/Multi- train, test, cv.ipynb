# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
import tensorflow as tf
tf.config.set_soft_device_placement(True)
tf.debugging.set_log_device_placement(True)

# %%
from glob import glob

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

import os
import platform

mpl.rc('font', size=14)

# %%
import pickle 

with open('/global/homes/v/vashisth/Binary/host_flux.data', 'rb') as filehandle:
    host_flux = pickle.load(filehandle)

# %%
with open('snia_flux.data', 'rb') as filehandle:
    # read the data as binary data stream
    snia_flux = pickle.load(filehandle)

# %%
with open('snib_flux.data', 'rb') as filehandle:
    # read the data as binary data stream
    snib_flux = pickle.load(filehandle)

# %%
with open('snibc_flux.data', 'rb') as filehandle:
    # read the data as binary data stream
    snibc_flux = pickle.load(filehandle)

# %%
with open('snic_flux.data', 'rb') as filehandle:
    # read the data as binary data stream
    snic_flux = pickle.load(filehandle)

# %%
with open('sniilp_flux .data', 'rb') as filehandle:
    # read the data as binary data stream
    sniilp_flux = pickle.load(filehandle)

# %%
with open('sniin_flux.data', 'rb') as filehandle:
    # read the data as binary data stream
    sniin_flux = pickle.load(filehandle)

# %%
with open('sniip_flux .data', 'rb') as filehandle:
    # read the data as binary data stream
    sniip_flux = pickle.load(filehandle)

# %%
nhost, nbins  = host_flux.shape
nsnia, nbins  = snia_flux.shape
nsnib, nbins  = snib_flux.shape
nsnibc, nbins = snibc_flux.shape
nsnic, nbins  = snic_flux.shape
nsniin, nbins = sniin_flux.shape
nsniilp, nbins = sniilp_flux.shape
nsniip, nbins = sniip_flux.shape
nhost, nsnia, nsnib, nsnibc, nsnic, nsniin, nsniilp, nsniip, nbins
# Out:
# (9969, 9964, 9958, 9971, 8269, 9949, 9948, 9962, 150)

# %%
import tensorflow as tf
from tensorflow.keras import utils, regularizers, callbacks, backend
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Reshape, Conv1D, MaxPooling1D, Dropout, Add, LSTM, Embedding
from tensorflow.keras.initializers import glorot_normal, glorot_uniform
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model

optimizer, n = Adam(lr=0.0002), 9

def network(input_shape, ncat, learning_rate=.0002, reg=0.0032, dropout=0.1, seed=1):
    """Define the CNN structure.
    Parameters
    ----------
    input_shape : int
    Shape of the input spectra.
    ncat : int
    Number of categories.
    learning_rate : float
    Learning rate.
    reg : float
    Regularization factor.
    dropout : float
    Dropout rate.
    seed : int
    Seed of initializer.

    Returns
    -------
    model : tensorflow.keras.Model
    A model instance of the network.
    """

    X_input = Input(input_shape, name='Input_Spec')

    # First convolutional layer.
    with backend.name_scope('Conv_1'):
        X = Conv1D(filters=8, kernel_size=n, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X_input)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(pool_size= 2)(X)

    # Second convolutional layer.
    with backend.name_scope('Conv_2'):
        X = Conv1D(filters=16, kernel_size=n, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)

    # Third convolutional layer.
    with backend.name_scope('Conv_3'):
        X = Conv1D(filters=32, kernel_size=n, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)

    # Fourth convolutional layer.
    with backend.name_scope('Conv_4'):
        X = Conv1D(filters=64, kernel_size=n, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)

    # Flatten to fully connected dense layer.
    with backend.name_scope('Dense_Layer'):
        X = Flatten()(X)
        X = Dense(256, kernel_regularizer=regularizers.l2(reg),
                  activation='relu')(X)
        X = Dropout(rate=dropout, seed=seed)(X)

    #     with backend.name_scope('Dense_Layer'):
    #         X = Flatten()(X)
    #         X = Dense(512, kernel_regularizer=regularizers.l2(reg),
    #                   activation='relu')(X)
    #         X = Dropout(rate=dropout, seed=seed)(X)

    # Output layer with sigmoid activation.
    with backend.name_scope('Output_Layer'):
        X = Dense(ncat, kernel_regularizer=regularizers.l2(reg),
              activation='softmax',name='Output_Classes')(X)

    model = Model(inputs=X_input, outputs=X, name='SNnet')

    # Set up optimizer, loss function, and optimization metrics.
    model.compile(optimizer=optimizer, loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
x = np.concatenate([host_flux, 
                    snia_flux,
                    snib_flux,
                    snibc_flux,
                    snic_flux,
                    sniin_flux,
                    sniilp_flux,
                    sniip_flux
                   ]).reshape(-1, nbins, 1)

labels = ['Host',
          'SN Ia',
          'SN Ib',
          'SN Ib/c',
          'SN Ic',
          'SN IIn',
          'SN IIL/P',
          'SN IIP']
ntypes = len(labels)

# Convert y-label array to appropriate categorical array
from tensorflow.keras.utils import to_categorical

y = to_categorical(
        np.concatenate([np.full(nhost, 0), 
                        np.full(nsnia, 1),
                        np.full(nsnib, 2),
                        np.full(nsnibc, 3),
                        np.full(nsnic, 4),
                        np.full(nsniin, 5),
                        np.full(nsniilp, 6),
                        np.full(nsniip, 7)
                       ]))

# %%
def split(trainsize,x,y):
    from sklearn.model_selection import train_test_split
    """This function splits x, y into train, test, cv
    cv and test are equally split"""
    n = trainsize
    # here a, b are (1-n) fraction of x, y
    x_train, a, y_train, b = train_test_split(x, y, train_size=n)
    # now we split a, b into half to get cv and test
    x_cv, x_test, y_cv, y_test = train_test_split(a,b, test_size=0.5)
    return x_train, x_test, x_cv,y_train, y_test, y_cv

# %% [markdown]
# # Splitting in 60, 20, 20

# %%
x_train, x_test, x_cv,y_train, y_test, y_cv = split(0.6,x,y)
len(x_train), len(x_test), len(x_cv),len(y_train), len(y_test), len(y_cv)
# Out:
# (46794, 15598, 15598, 46794, 15598, 15598)

# %%
model = network((nbins, 1),ncat=y.shape[1])
hist = model.fit(x_train, y_train, batch_size=65, epochs=50, validation_data=(x_test, y_test), shuffle=True)
# Out:
# Epoch 1/50
# 720/720 [==============================] - 15s 21ms/step - loss: 2.6668 - accuracy: 0.4279 - val_loss: 2.1828 - val_accuracy: 0.5430
# Epoch 2/50
# 720/720 [==============================] - 15s 21ms/step - loss: 1.9411 - accuracy: 0.5939 - val_loss: 1.7600 - val_accuracy: 0.6251
# Epoch 3/50
# 720/720 [==============================] - 15s 21ms/step - loss: 1.6399 - accuracy: 0.6373 - val_loss: 1.5365 - val_accuracy: 0.6586
# Epoch 4/50
# 720/720 [==============================] - 15s 21ms/step - loss: 1.4557 - accuracy: 0.6649 - val_loss: 1.4088 - val_accuracy: 0.6709
# Epoch 5/50
# 720/720 [==============================] - 15s 20ms/step - loss: 1.3332 - accuracy: 0.6796 - val_loss: 1.3175 - val_accuracy: 0.6739
# Epoch 6/50
# 720/720 [==============================] - 15s 20ms/step - loss: 1.2462 - accuracy: 0.6916 - val_loss: 1.2544 - val_accuracy: 0.6816
# Epoch 7/50
# 720/720 [==============================] - 15s 21ms/step - loss: 1.1828 - accuracy: 0.6979 - val_loss: 1.1999 - val_accuracy: 0.6841
# Epoch 8/50
# 720/720 [==============================] - 15s 21ms/step - loss: 1.1334 - accuracy: 0.7051 - val_loss: 1.1879 - val_accuracy: 0.6834
# Epoch 9/50
# 720/720 [==============================] - 16s 22ms/step - loss: 1.0963 - accuracy: 0.7118 - val_loss: 1.1557 - val_accuracy: 0.6841
# Epoch 10/50
# 720/720 [==============================] - 15s 21ms/step - loss: 1.0639 - accuracy: 0.7151 - val_loss: 1.1408 - val_accuracy: 0.6870
# Epoch 11/50
# 720/720 [==============================] - 15s 21ms/step - loss: 1.0408 - accuracy: 0.7198 - val_loss: 1.1259 - val_accuracy: 0.6891
# Epoch 12/50
# 720/720 [==============================] - 15s 21ms/step - loss: 1.0180 - accuracy: 0.7233 - val_loss: 1.1046 - val_accuracy: 0.6919
# Epoch 13/50
# 720/720 [==============================] - 15s 21ms/step - loss: 1.0005 - accuracy: 0.7274 - val_loss: 1.0833 - val_accuracy: 0.6980
# Epoch 14/50
# 720/720 [==============================] - 15s 21ms/step - loss: 0.9794 - accuracy: 0.7340 - val_loss: 1.0665 - val_accuracy: 0.7027
# Epoch 15/50
# 720/720 [==============================] - 15s 21ms/step - loss: 0.9652 - accuracy: 0.7366 - val_loss: 1.0741 - val_accuracy: 0.6953
# Epoch 16/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.9557 - accuracy: 0.7383 - val_loss: 1.0724 - val_accuracy: 0.6919
# Epoch 17/50
# 720/720 [==============================] - 15s 21ms/step - loss: 0.9441 - accuracy: 0.7426 - val_loss: 1.0523 - val_accuracy: 0.7013
# Epoch 18/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.9320 - accuracy: 0.7452 - val_loss: 1.0843 - val_accuracy: 0.6891
# Epoch 19/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.9210 - accuracy: 0.7473 - val_loss: 1.0534 - val_accuracy: 0.6991
# Epoch 20/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.9109 - accuracy: 0.7521 - val_loss: 1.0482 - val_accuracy: 0.7036
# Epoch 21/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.9049 - accuracy: 0.7539 - val_loss: 1.0839 - val_accuracy: 0.6929
# Epoch 22/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.8959 - accuracy: 0.7558 - val_loss: 1.0524 - val_accuracy: 0.7009
# Epoch 23/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.8858 - accuracy: 0.7604 - val_loss: 1.0434 - val_accuracy: 0.7041
# Epoch 24/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.8800 - accuracy: 0.7607 - val_loss: 1.0853 - val_accuracy: 0.6921
# Epoch 25/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.8735 - accuracy: 0.7626 - val_loss: 1.0877 - val_accuracy: 0.6907
# Epoch 26/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.8655 - accuracy: 0.7679 - val_loss: 1.0757 - val_accuracy: 0.6938
# Epoch 27/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.8595 - accuracy: 0.7691 - val_loss: 1.0598 - val_accuracy: 0.6993
# Epoch 28/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.8505 - accuracy: 0.7718 - val_loss: 1.0625 - val_accuracy: 0.6995
# Epoch 29/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.8481 - accuracy: 0.7721 - val_loss: 1.0669 - val_accuracy: 0.6989
# Epoch 30/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.8433 - accuracy: 0.7742 - val_loss: 1.0669 - val_accuracy: 0.6984
# Epoch 31/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.8344 - accuracy: 0.7771 - val_loss: 1.0842 - val_accuracy: 0.6932
# Epoch 32/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.8321 - accuracy: 0.7786 - val_loss: 1.1109 - val_accuracy: 0.6859
# Epoch 33/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.8254 - accuracy: 0.7829 - val_loss: 1.0833 - val_accuracy: 0.6928
# Epoch 34/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.8191 - accuracy: 0.7847 - val_loss: 1.1323 - val_accuracy: 0.6807
# Epoch 35/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.8128 - accuracy: 0.7867 - val_loss: 1.1182 - val_accuracy: 0.6860
# Epoch 36/50
# 720/720 [==============================] - 15s 21ms/step - loss: 0.8070 - accuracy: 0.7877 - val_loss: 1.0919 - val_accuracy: 0.6892
# Epoch 37/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.8039 - accuracy: 0.7894 - val_loss: 1.0902 - val_accuracy: 0.6936
# Epoch 38/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.8014 - accuracy: 0.7912 - val_loss: 1.1258 - val_accuracy: 0.6796
# Epoch 39/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.7929 - accuracy: 0.7959 - val_loss: 1.1390 - val_accuracy: 0.6839
# Epoch 40/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.7913 - accuracy: 0.7939 - val_loss: 1.1267 - val_accuracy: 0.6881
# Epoch 41/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.7861 - accuracy: 0.7973 - val_loss: 1.1188 - val_accuracy: 0.6871
# Epoch 42/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.7814 - accuracy: 0.7987 - val_loss: 1.1580 - val_accuracy: 0.6861
# Epoch 43/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.7780 - accuracy: 0.8015 - val_loss: 1.1544 - val_accuracy: 0.6780
# Epoch 44/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.7739 - accuracy: 0.8009 - val_loss: 1.1345 - val_accuracy: 0.6889
# Epoch 45/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.7684 - accuracy: 0.8047 - val_loss: 1.1214 - val_accuracy: 0.6869
# Epoch 46/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.7688 - accuracy: 0.8054 - val_loss: 1.1525 - val_accuracy: 0.6865
# Epoch 47/50
# 720/720 [==============================] - 14s 20ms/step - loss: 0.7617 - accuracy: 0.8077 - val_loss: 1.1893 - val_accuracy: 0.6686
# Epoch 48/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.7586 - accuracy: 0.8094 - val_loss: 1.1843 - val_accuracy: 0.6746
# Epoch 49/50
# 720/720 [==============================] - 15s 21ms/step - loss: 0.7538 - accuracy: 0.8105 - val_loss: 1.1646 - val_accuracy: 0.6796
# Epoch 50/50
# 720/720 [==============================] - 15s 20ms/step - loss: 0.7504 - accuracy: 0.8121 - val_loss: 1.1475 - val_accuracy: 0.6930

# %%
model.save('multi(60,20,20)')
# Out:
# WARNING:tensorflow:From /usr/common/software/tensorflow/gpu-tensorflow/2.2.0-py37/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: multi(60,20,20)/assets

# %%
# Plotting epoch vs accuracy
title = "Adam (lr) with kernel = {0}".format(n)
fig, axes = plt.subplots(1,2, figsize=(14,6), sharex=True)
fig.suptitle(title, fontsize=16)
nepoch = len(hist.history['loss'])
epochs = np.arange(1, nepoch+1)

ax = axes[0]
ax.plot(epochs, hist.history['accuracy'], label='acc')
ax.plot(epochs, hist.history['val_accuracy'], label='val_acc')
ax.set(xlabel='training epoch',
       ylabel='accuracy',
       xlim=(0, nepoch),
       ylim=(0.5,1.05))
ax.set_title('Maximum val_acc = {0:2.3f}'.format(max(hist.history['val_accuracy'])))
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

ax = axes[1]
ax.plot(epochs, hist.history['loss'], label='loss')
ax.plot(epochs, hist.history['val_loss'], label='val_loss')
ax.set(xlabel='training epoch',
       ylabel='loss',
       xlim=(0, nepoch),
       ylim=(0.,2.0))
ax.set_title('Minimum val_loss = {0:2.3f}'.format(min(hist.history['val_loss'])))
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

# %%
# Print ROC and PR Curve
y_pred = model.predict(x_cv)

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

fig, axes = plt.subplots(1,2, figsize=(10,5), sharex=True, sharey=True)

all_fpr = None
all_tpr = None

fpr = dict()
tpr = dict()
pre = dict()
rec = dict()
for i in range(ntypes):
    fpr[i], tpr[i], _ = roc_curve(y_cv[:,i], y_pred[:,i])        
    roc_auc = auc(fpr[i], tpr[i])

    ax = axes[0]
    ax.plot(fpr[i], tpr[i], label='{}; AUC = {:.2f}'.format(labels[i], roc_auc))
    ax.grid(ls=':')

    pre[i], rec[i], _ = precision_recall_curve(y_cv[:,i], y_pred[:,i])

    ax = axes[1]
    ax.plot(rec[i], pre[i])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(ntypes)]))
mean_tpr = np.zeros_like(all_fpr)
for i in range(ntypes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
fpr['macro'] = all_fpr
tpr['macro'] = mean_tpr / ntypes
fpr['macro'] = np.insert(fpr['macro'], 0, 0)
tpr['macro'] = np.insert(tpr['macro'], 0, 0)
roc_auc_macro = auc(fpr['macro'], tpr['macro'])

ax = axes[0]
ax.plot(fpr['macro'], tpr['macro'], lw=3, ls='--', color='k',
        label='cat. avg. ROC\nAUC = {:.2f}'.format(roc_auc_macro))
ax.set(xlim=(-0.01,1.01), xlabel='FPR = FP / (FP + TN)',
       ylim=(-0.01,1.01), ylabel='recall (TPR) = TP / (TP + FN)',
       title='ROC: AUC = {:.3f}'.format(roc_auc_macro),
       aspect='equal')
ax.legend(fontsize=10, loc='lower right')

ax = axes[1]
pre['micro'], rec['micro'], _ = precision_recall_curve(y_cv.ravel(), y_pred.ravel())
ax.plot(rec['micro'], pre['micro'], lw=3, ls='--', color='k')

f_scores = np.linspace(0.1, 0.9, num=5)
for f_score in f_scores:
    x_ = np.linspace(0.01, 1)
    y_ = f_score * x_ / (2 * x_ - f_score)
    l, = plt.plot(x_[y_ >= 0], y_[y_ >= 0], color='k', ls='--', alpha=0.3)
    ax.annotate(' $F_{{1}}={0:0.1f}$'.format(f_score), xy=(1.01, y_[45]-0.02),
                fontsize=12, alpha=0.8)
ax.grid(ls=':')
ax.set(xlabel='recall (TPR) = TP / (TP + FN)',
       ylabel='precision = TP / (TP + FP)',
       title='Average precision = {:.3f}'.format(average_precision_score(y_cv, y_pred)),
       aspect='equal')

fig.tight_layout()

# %%
# CM
from sklearn.metrics import confusion_matrix

# In the multilabel classifier, test that the maximum of the
# output matrix of values matches.
cm = confusion_matrix(y_cv.argmax(axis=1), y_pred.argmax(axis=1))
cmnorm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

fig, ax = plt.subplots(1,1, figsize=(10,9))

im = ax.imshow(cmnorm, cmap='Blues', vmin=0, vmax=1)
cb = ax.figure.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cb.set_label('correct label fraction')

ax.set(aspect='equal',
       xlabel='predicted label',
       xticks=np.arange(cm.shape[1]),
       xticklabels=labels,
       ylabel='true label',
       yticks=np.arange(cm.shape[1]),
       yticklabels=labels)

thresh = 0.5*cm.max()
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, '{:.3f}\n({:d})'.format(cmnorm[i,j], cm[i,j]),
                ha='center', va='center',
                color='black' if cm[i,j] < thresh else 'white')
plt.ylim([7.5,-.5])
fig.tight_layout()

# %% [markdown]
# # Splitting in 70, 15, 15

# %%
x_train, x_test, x_cv,y_train, y_test, y_cv = split(0.7,x,y)
len(x_train), len(x_test), len(x_cv),len(y_train), len(y_test), len(y_cv)
# Out:
# (54593, 11699, 11698, 54593, 11699, 11698)

# %%
model = network((nbins, 1),ncat=y.shape[1])
hist = model.fit(x_train, y_train, batch_size=65, epochs=50, 
                 validation_data=(x_test, y_test), shuffle=True)
# Save the entire model as a SavedModel.
# Out:
# Epoch 1/50
# 840/840 [==============================] - 22s 27ms/step - loss: 2.0145 - accuracy: 0.5364 - val_loss: 1.5754 - val_accuracy: 0.6301
# Epoch 2/50
# 840/840 [==============================] - 22s 27ms/step - loss: 1.4442 - accuracy: 0.6485 - val_loss: 1.3617 - val_accuracy: 0.6683
# Epoch 3/50
# 840/840 [==============================] - 22s 26ms/step - loss: 1.2909 - accuracy: 0.6716 - val_loss: 1.2579 - val_accuracy: 0.6772
# Epoch 4/50
# 840/840 [==============================] - 20s 24ms/step - loss: 1.2030 - accuracy: 0.6846 - val_loss: 1.1908 - val_accuracy: 0.6852
# Epoch 5/50
# 840/840 [==============================] - 19s 22ms/step - loss: 1.1408 - accuracy: 0.6943 - val_loss: 1.1550 - val_accuracy: 0.6900
# Epoch 6/50
# 840/840 [==============================] - 18s 21ms/step - loss: 1.0986 - accuracy: 0.7009 - val_loss: 1.1221 - val_accuracy: 0.6936
# Epoch 7/50
# 840/840 [==============================] - 18s 22ms/step - loss: 1.0637 - accuracy: 0.7086 - val_loss: 1.1594 - val_accuracy: 0.6668
# Epoch 8/50
# 840/840 [==============================] - 18s 21ms/step - loss: 1.0376 - accuracy: 0.7114 - val_loss: 1.0741 - val_accuracy: 0.7037
# Epoch 9/50
# 840/840 [==============================] - 18s 21ms/step - loss: 1.0161 - accuracy: 0.7181 - val_loss: 1.0970 - val_accuracy: 0.6857
# Epoch 10/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.9941 - accuracy: 0.7223 - val_loss: 1.0655 - val_accuracy: 0.6987
# Epoch 11/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.9814 - accuracy: 0.7251 - val_loss: 1.0555 - val_accuracy: 0.7029
# Epoch 12/50
# 840/840 [==============================] - 18s 22ms/step - loss: 0.9644 - accuracy: 0.7289 - val_loss: 1.0447 - val_accuracy: 0.7051
# Epoch 13/50
# 840/840 [==============================] - 17s 21ms/step - loss: 0.9516 - accuracy: 0.7338 - val_loss: 1.0425 - val_accuracy: 0.6987
# Epoch 14/50
# 840/840 [==============================] - 18s 22ms/step - loss: 0.9420 - accuracy: 0.7354 - val_loss: 1.0655 - val_accuracy: 0.6923
# Epoch 15/50
# 840/840 [==============================] - 17s 21ms/step - loss: 0.9303 - accuracy: 0.7380 - val_loss: 1.0422 - val_accuracy: 0.7038
# Epoch 16/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.9209 - accuracy: 0.7403 - val_loss: 1.0446 - val_accuracy: 0.6959
# Epoch 17/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.9139 - accuracy: 0.7427 - val_loss: 1.0373 - val_accuracy: 0.7051
# Epoch 18/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.9056 - accuracy: 0.7459 - val_loss: 1.0488 - val_accuracy: 0.6961
# Epoch 19/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8983 - accuracy: 0.7471 - val_loss: 1.0196 - val_accuracy: 0.7043
# Epoch 20/50
# 840/840 [==============================] - 17s 21ms/step - loss: 0.8901 - accuracy: 0.7507 - val_loss: 1.0348 - val_accuracy: 0.6997
# Epoch 21/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8847 - accuracy: 0.7506 - val_loss: 1.0280 - val_accuracy: 0.7067
# Epoch 22/50
# 840/840 [==============================] - 17s 21ms/step - loss: 0.8766 - accuracy: 0.7563 - val_loss: 1.0411 - val_accuracy: 0.6997
# Epoch 23/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8703 - accuracy: 0.7570 - val_loss: 1.0265 - val_accuracy: 0.7072
# Epoch 24/50
# 840/840 [==============================] - 17s 20ms/step - loss: 0.8650 - accuracy: 0.7583 - val_loss: 1.0592 - val_accuracy: 0.6965
# Epoch 25/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8605 - accuracy: 0.7610 - val_loss: 1.0383 - val_accuracy: 0.7033
# Epoch 26/50
# 840/840 [==============================] - 17s 21ms/step - loss: 0.8549 - accuracy: 0.7621 - val_loss: 1.0369 - val_accuracy: 0.7014
# Epoch 27/50
# 840/840 [==============================] - 17s 21ms/step - loss: 0.8496 - accuracy: 0.7630 - val_loss: 1.0357 - val_accuracy: 0.7000
# Epoch 28/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8450 - accuracy: 0.7650 - val_loss: 1.0796 - val_accuracy: 0.6912
# Epoch 29/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8404 - accuracy: 0.7678 - val_loss: 1.0479 - val_accuracy: 0.6972
# Epoch 30/50
# 840/840 [==============================] - 17s 21ms/step - loss: 0.8330 - accuracy: 0.7690 - val_loss: 1.0458 - val_accuracy: 0.7020
# Epoch 31/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8301 - accuracy: 0.7711 - val_loss: 1.0594 - val_accuracy: 0.7034
# Epoch 32/50
# 840/840 [==============================] - 17s 21ms/step - loss: 0.8243 - accuracy: 0.7753 - val_loss: 1.0685 - val_accuracy: 0.6944
# Epoch 33/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8199 - accuracy: 0.7756 - val_loss: 1.1036 - val_accuracy: 0.6821
# Epoch 34/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8170 - accuracy: 0.7764 - val_loss: 1.0821 - val_accuracy: 0.6888
# Epoch 35/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8116 - accuracy: 0.7785 - val_loss: 1.0669 - val_accuracy: 0.7013
# Epoch 36/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8091 - accuracy: 0.7823 - val_loss: 1.1110 - val_accuracy: 0.6806
# Epoch 37/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.8044 - accuracy: 0.7812 - val_loss: 1.0714 - val_accuracy: 0.6961
# Epoch 38/50
# 840/840 [==============================] - 18s 22ms/step - loss: 0.8001 - accuracy: 0.7828 - val_loss: 1.0692 - val_accuracy: 0.7015
# Epoch 39/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.7964 - accuracy: 0.7842 - val_loss: 1.0709 - val_accuracy: 0.6952
# Epoch 40/50
# 840/840 [==============================] - 18s 22ms/step - loss: 0.7956 - accuracy: 0.7863 - val_loss: 1.0811 - val_accuracy: 0.6917
# Epoch 41/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.7912 - accuracy: 0.7894 - val_loss: 1.0643 - val_accuracy: 0.6957
# Epoch 42/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.7879 - accuracy: 0.7890 - val_loss: 1.0939 - val_accuracy: 0.6984
# Epoch 43/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.7810 - accuracy: 0.7920 - val_loss: 1.0787 - val_accuracy: 0.7000
# Epoch 44/50
# 840/840 [==============================] - 18s 22ms/step - loss: 0.7778 - accuracy: 0.7931 - val_loss: 1.1943 - val_accuracy: 0.6642
# Epoch 45/50
# 840/840 [==============================] - 18s 22ms/step - loss: 0.7782 - accuracy: 0.7948 - val_loss: 1.1323 - val_accuracy: 0.6831
# Epoch 46/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.7772 - accuracy: 0.7932 - val_loss: 1.1051 - val_accuracy: 0.6965
# Epoch 47/50
# 840/840 [==============================] - 17s 21ms/step - loss: 0.7707 - accuracy: 0.7962 - val_loss: 1.1195 - val_accuracy: 0.6825
# Epoch 48/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.7713 - accuracy: 0.7962 - val_loss: 1.0878 - val_accuracy: 0.6944
# Epoch 49/50
# 840/840 [==============================] - 18s 21ms/step - loss: 0.7659 - accuracy: 0.7995 - val_loss: 1.1465 - val_accuracy: 0.6841
# Epoch 50/50
# 840/840 [==============================] - 18s 22ms/step - loss: 0.7641 - accuracy: 0.7993 - val_loss: 1.1131 - val_accuracy: 0.6848

# %%
model.save('multi(70,15,15)')
# Out:
# INFO:tensorflow:Assets written to: multi(70,15,15)/assets

# %%
# Plotting epoch vs accuracy 
fig, axes = plt.subplots(1,2, figsize=(14,6), sharex=True)
fig.suptitle(title, fontsize=16)
nepoch = len(hist.history['loss'])
epochs = np.arange(1, nepoch+1)
title = "Adam (lr) with kernel = {0}".format(n)
ax = axes[0]
ax.plot(epochs, hist.history['acc'], label='acc')
ax.plot(epochs, hist.history['val_acc'], label='val_acc')
ax.set(xlabel='training epoch',
       ylabel='accuracy',
       xlim=(0, nepoch),
       ylim=(0.5,1.05))
ax.set_title('Maximum val_acc = {0:2.3f}'.format(max(hist.history['val_acc'])))
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

ax = axes[1]
ax.plot(epochs, hist.history['loss'], label='loss')
ax.plot(epochs, hist.history['val_loss'], label='val_loss')
ax.set(xlabel='training epoch',
       ylabel='loss',
       xlim=(0, nepoch),
       ylim=(0.,2.0))
ax.set_title('Minimum val_loss = {0:2.3f}'.format(min(hist.history['val_loss'])))
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

# %%
# Print ROC and PR Curve
y_pred = model.predict(x_cv)

from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

fig, axes = plt.subplots(1,2, figsize=(10,5), sharex=True, sharey=True)

all_fpr = None
all_tpr = None

fpr = dict()
tpr = dict()
pre = dict()
rec = dict()
for i in range(ntypes):
    fpr[i], tpr[i], _ = roc_curve(y_cv[:,i], y_pred[:,i])        
    roc_auc = auc(fpr[i], tpr[i])

    ax = axes[0]
    ax.plot(fpr[i], tpr[i], label='{}; AUC = {:.2f}'.format(labels[i], roc_auc))
    ax.grid(ls=':')

    pre[i], rec[i], _ = precision_recall_curve(y_cv[:,i], y_pred[:,i])

    ax = axes[1]
    ax.plot(rec[i], pre[i])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(ntypes)]))
mean_tpr = np.zeros_like(all_fpr)
for i in range(ntypes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
fpr['macro'] = all_fpr
tpr['macro'] = mean_tpr / ntypes
fpr['macro'] = np.insert(fpr['macro'], 0, 0)
tpr['macro'] = np.insert(tpr['macro'], 0, 0)
roc_auc_macro = auc(fpr['macro'], tpr['macro'])

ax = axes[0]
ax.plot(fpr['macro'], tpr['macro'], lw=3, ls='--', color='k',
        label='cat. avg. ROC\nAUC = {:.2f}'.format(roc_auc_macro))
ax.set(xlim=(-0.01,1.01), xlabel='FPR = FP / (FP + TN)',
       ylim=(-0.01,1.01), ylabel='recall (TPR) = TP / (TP + FN)',
       title='ROC: AUC = {:.3f}'.format(roc_auc_macro),
       aspect='equal')
ax.legend(fontsize=10, loc='lower right')

ax = axes[1]
pre['micro'], rec['micro'], _ = precision_recall_curve(y_cv.ravel(), y_pred.ravel())
ax.plot(rec['micro'], pre['micro'], lw=3, ls='--', color='k')

f_scores = np.linspace(0.1, 0.9, num=5)
for f_score in f_scores:
    x_ = np.linspace(0.01, 1)
    y_ = f_score * x_ / (2 * x_ - f_score)
    l, = plt.plot(x_[y_ >= 0], y_[y_ >= 0], color='k', ls='--', alpha=0.3)
    ax.annotate(' $F_{{1}}={0:0.1f}$'.format(f_score), xy=(1.01, y_[45]-0.02),
                fontsize=12, alpha=0.8)
ax.grid(ls=':')
ax.set(xlabel='recall (TPR) = TP / (TP + FN)',
       ylabel='precision = TP / (TP + FP)',
       title='Average precision = {:.3f}'.format(average_precision_score(y_cv, y_pred)),
       aspect='equal')

fig.tight_layout()

# CM
from sklearn.metrics import confusion_matrix

# In the multilabel classifier, test that the maximum of the
# output matrix of values matches.
cm = confusion_matrix(y_cv.argmax(axis=1), y_pred.argmax(axis=1))
cmnorm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

fig, ax = plt.subplots(1,1, figsize=(10,9))

im = ax.imshow(cmnorm, cmap='Blues', vmin=0, vmax=1)
cb = ax.figure.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cb.set_label('correct label fraction')

ax.set(aspect='equal',
       xlabel='predicted label',
       xticks=np.arange(cm.shape[1]),
       xticklabels=labels,
       ylabel='true label',
       yticks=np.arange(cm.shape[1]),
       yticklabels=labels)

thresh = 0.5*cm.max()
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, '{:.3f}\n({:d})'.format(cmnorm[i,j], cm[i,j]),
                ha='center', va='center',
                color='black' if cm[i,j] < thresh else 'white')
plt.ylim([7.5,-.5])
fig.tight_layout()
